# %% [raw]
# Predict Housing Prices (Regression)
# Problem: Given features like square footage, number of bedrooms, and location, predict the price of a house.

# %%
# Start by importing all the tools we'll be using.
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import fetch_california_housing

# %%
# Load the dataset into a pandas DataFrame.
housing = fetch_california_housing(as_frame=True)
df = housing.frame
df["target"] = housing.target
print('the list of colummn: {}'.format(housing.feature_names))
print('Visualising the first values of out dataframe:\n{}\n'.format(df.head()))

# Check for missing values: df.isnull().sum()
print('Checking if there is any missing values:\n{}\n'.format(df.isnull().sum()))

# Look at statistical summaries: df.describe()
print('Take a look at statical summaries:\n{}\n'.format(df.describe()))

# Visualize relationships between features and the target variable (target):
sns.histplot(df['target'], kde=True)
plt.show()
# Out:
# the list of colummn: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# Visualising the first values of out dataframe:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal  target
# 0    -122.23        4.526   4.526
# 1    -122.22        3.585   3.585
# 2    -122.24        3.521   3.521
# 3    -122.25        3.413   3.413
# 4    -122.25        3.422   3.422
#
# Checking if there is any missing values:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# ...

# %%
# Split the data into features (X) and the target variable (y). Then, split it again into training and testing sets.

X = df.drop('target', axis=1) # Features
Y = df['target'] # Target variable

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print('training set size: {}'.format(X_train.shape[0]))
print('testing set size: {}'.format(X_test.shape[0]))
# Out:
# training set size: 16512
# testing set size: 4128

# %%
 # Building and Training a linear regression Model
model = LinearRegression()
model.fit(X_train, Y_train) # This is where the model learns the relationship between the features and the target variable.
# Out:
# LinearRegression()

# %%
# Evaluate the model by using the test set to see how well your model performs.
Y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print('Mean Squared Error Result: {}'.format(mse))
print('R2 Result: {}'.format(r2))
# Out:
# Mean Squared Error Result: 8.705021914459036e-27
# R2 Result: 1.0
